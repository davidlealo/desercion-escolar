# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('data/tablas/seguimiento1stsem2018.csv', sep=';')

# %% [markdown]
# # Mapa de correlación

# %%
df.head()
# Out:
#    AGNO  RBD  DGV_RBD                  NOM_RBD  COD_REG_RBD NOM_REG_RBD_A  \
# 0  2018    1        9  LICEO POLITECNICO ARICA           15           AYP
# 1  2018    1        9  LICEO POLITECNICO ARICA           15           AYP
# 2  2018    1        9  LICEO POLITECNICO ARICA           15           AYP
# 3  2018    1        9  LICEO POLITECNICO ARICA           15           AYP
# 4  2018    1        9  LICEO POLITECNICO ARICA           15           AYP
#
#    COD_PRO_RBD  COD_COM_RBD NOM_COM_RBD  COD_DEPROV_RBD  ...  \
# 0          151        15101       ARICA             151  ...
# 1          151        15101       ARICA             151  ...
# 2          151        15101       ARICA             151  ...
# 3          151        15101       ARICA             151  ...
# 4          151        15101       ARICA             151  ...
#
#   ASIS_PROMEDIO_ABRIL  DIAS_ASISTIDOS_MAYO  DIAS_TRABAJADOS_MAYO  \
# 0                 1.0                    9                    21
# 1                 0.0                    0                    21
# 2                 0.0                    0                    21
# 3                 0.0                    0                    21
# 4                 0.0                    0                    21
#
#    ASIS_PROMEDIO_MAYO  DIAS_ASISTIDOS_JUNIO  DIAS_TRABAJADOS_JUNIO  \
# 0              0.4286                    15                     18
# 1              0.0000                     0                     18
# 2              0.0000                     0                     18
# 3              0.0000                     0                     18
# 4              0.0000                     0                     18
#
#    ASIS_PROMEDIO_JUNIO  DIAS_ASISTIDOS_JULIO DIAS_TRABAJADOS_JULIO  \
# 0               0.8333                     6                     9
# 1               0.0000                     0                     9
# 2               0.0000                     0                     9
# 3               0.0000                     0                     9
# 4               0.0000                     0                     9
#
#    ASIS_PROMEDIO_JULIO
# 0               0.6667
# 1               0.0000
# 2               0.0000
# 3               0.0000
# 4               0.0000
#
# [5 rows x 54 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6758035 entries, 0 to 6758034
# Data columns (total 54 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   AGNO                   int64
#  1   RBD                    int64
#  2   DGV_RBD                int64
#  3   NOM_RBD                object
#  4   COD_REG_RBD            int64
#  5   NOM_REG_RBD_A          object
#  6   COD_PRO_RBD            int64
#  7   COD_COM_RBD            int64
#  8   NOM_COM_RBD            object
#  9   COD_DEPROV_RBD         int64
#  10  NOM_DEPROV_RBD         object
#  11  COD_DEPE               int64
#  12  COD_DEPE2              int64
#  13  RURAL_RBD              int64
#  14  ESTADO_ESTAB           int64
#  15  COD_ENSE               int64
#  16  COD_ENSE2              int64
#  17  COD_GRADO              int64
#  18  LET_CUR                object
#  19  COD_JOR                int64
#  20  COD_TIP_CUR            int64
#  21  COD_DES_CUR            int64
#  22  MRUN                   int64
#  23  GEN_ALU                int64
#  24  EDAD_ALU               int64
#  25  COD_REG_ALU            int64
#  26  COD_COM_ALU            int64
#  27  NOM_COM_ALU            object
#  28  COD_RAMA               int64
#  29  COD_SEC                int64
#  30  COD_ESPE               int64
#  31  PROM_GRAL              float64
#  32  ASISTENCIA             int64
#  33  SIT_FIN                object
#  34  SIT_FIN_R              object
#  35  DESERTOR               int64
#  36  COD_MEN                float64
#  37  AGNO_NAC_ALU           int64
#  38  MES_NAC_ALU            int64
#  39  DIAS_ASISTIDOS_MARZO   int64
#  40  DIAS_TRABAJADOS_MARZO  int64
#  41  ASIS_PROMEDIO_MARZO    float64
#  42  DIAS_ASISTIDOS_ABRIL   int64
#  43  DIAS_TRABAJADOS_ABRIL  int64
#  44  ASIS_PROMEDIO_ABRIL    float64
#  45  DIAS_ASISTIDOS_MAYO    int64
#  46  DIAS_TRABAJADOS_MAYO   int64
#  47  ASIS_PROMEDIO_MAYO     float64
#  48  DIAS_ASISTIDOS_JUNIO   int64
#  49  DIAS_TRABAJADOS_JUNIO  int64
#  50  ASIS_PROMEDIO_JUNIO    float64
#  51  DIAS_ASISTIDOS_JULIO   int64
#  52  DIAS_TRABAJADOS_JULIO  int64
#  53  ASIS_PROMEDIO_JULIO    float64
# dtypes: float64(7), int64(39), object(8)
# memory usage: 2.7+ GB

# %%
# Datos nulos
df.isnull().sum()
# Out:
# AGNO                          0
# RBD                           0
# DGV_RBD                       0
# NOM_RBD                       0
# COD_REG_RBD                   0
# NOM_REG_RBD_A                 0
# COD_PRO_RBD                   0
# COD_COM_RBD                   0
# NOM_COM_RBD                   0
# COD_DEPROV_RBD                0
# NOM_DEPROV_RBD                0
# COD_DEPE                      0
# COD_DEPE2                     0
# RURAL_RBD                     0
# ESTADO_ESTAB                  0
# COD_ENSE                      0
# COD_ENSE2                     0
# COD_GRADO                     0
# LET_CUR                       0
# COD_JOR                       0
# COD_TIP_CUR                   0
# COD_DES_CUR                   0
# MRUN                          0
# GEN_ALU                       0
# EDAD_ALU                      0
# COD_REG_ALU                   0
# COD_COM_ALU                   0
# NOM_COM_ALU                   0
# COD_RAMA                      0
# COD_SEC                       0
# COD_ESPE                      0
# PROM_GRAL                     0
# ASISTENCIA                    0
# SIT_FIN                       0
# SIT_FIN_R                     0
# DESERTOR                      0
# COD_MEN                  602650
# AGNO_NAC_ALU                  0
# MES_NAC_ALU                   0
# DIAS_ASISTIDOS_MARZO          0
# DIAS_TRABAJADOS_MARZO         0
# ASIS_PROMEDIO_MARZO           0
# DIAS_ASISTIDOS_ABRIL          0
# DIAS_TRABAJADOS_ABRIL         0
# ASIS_PROMEDIO_ABRIL           0
# DIAS_ASISTIDOS_MAYO           0
# DIAS_TRABAJADOS_MAYO          0
# ASIS_PROMEDIO_MAYO            0
# DIAS_ASISTIDOS_JUNIO          0
# DIAS_TRABAJADOS_JUNIO         0
# ASIS_PROMEDIO_JUNIO           0
# DIAS_ASISTIDOS_JULIO          0
# DIAS_TRABAJADOS_JULIO         0
# ASIS_PROMEDIO_JULIO           0
# dtype: int64

# %%
# Drop AGNO y COD_MEN
df = df.drop(['AGNO', 'COD_MEN'], axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6758035 entries, 0 to 6758034
# Data columns (total 52 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   RBD                    int64
#  1   DGV_RBD                int64
#  2   NOM_RBD                object
#  3   COD_REG_RBD            int64
#  4   NOM_REG_RBD_A          object
#  5   COD_PRO_RBD            int64
#  6   COD_COM_RBD            int64
#  7   NOM_COM_RBD            object
#  8   COD_DEPROV_RBD         int64
#  9   NOM_DEPROV_RBD         object
#  10  COD_DEPE               int64
#  11  COD_DEPE2              int64
#  12  RURAL_RBD              int64
#  13  ESTADO_ESTAB           int64
#  14  COD_ENSE               int64
#  15  COD_ENSE2              int64
#  16  COD_GRADO              int64
#  17  LET_CUR                object
#  18  COD_JOR                int64
#  19  COD_TIP_CUR            int64
#  20  COD_DES_CUR            int64
#  21  MRUN                   int64
#  22  GEN_ALU                int64
#  23  EDAD_ALU               int64
#  24  COD_REG_ALU            int64
#  25  COD_COM_ALU            int64
#  26  NOM_COM_ALU            object
#  27  COD_RAMA               int64
#  28  COD_SEC                int64
#  29  COD_ESPE               int64
#  30  PROM_GRAL              float64
#  31  ASISTENCIA             int64
#  32  SIT_FIN                object
#  33  SIT_FIN_R              object
#  34  DESERTOR               int64
#  35  AGNO_NAC_ALU           int64
#  36  MES_NAC_ALU            int64
#  37  DIAS_ASISTIDOS_MARZO   int64
#  38  DIAS_TRABAJADOS_MARZO  int64
#  39  ASIS_PROMEDIO_MARZO    float64
#  40  DIAS_ASISTIDOS_ABRIL   int64
#  41  DIAS_TRABAJADOS_ABRIL  int64
#  42  ASIS_PROMEDIO_ABRIL    float64
#  43  DIAS_ASISTIDOS_MAYO    int64
#  44  DIAS_TRABAJADOS_MAYO   int64
#  45  ASIS_PROMEDIO_MAYO     float64
#  46  DIAS_ASISTIDOS_JUNIO   int64
#  47  DIAS_TRABAJADOS_JUNIO  int64
#  48  ASIS_PROMEDIO_JUNIO    float64
#  49  DIAS_ASISTIDOS_JULIO   int64
#  50  DIAS_TRABAJADOS_JULIO  int64
#  51  ASIS_PROMEDIO_JULIO    float64
# dtypes: float64(6), int64(38), object(8)
# memory usage: 2.6+ GB

# %%
df = df.drop(['NOM_RBD'], axis=1)

# %%
df = df.drop(['NOM_REG_RBD_A'], axis=1)

# %%
df = df.drop(['NOM_COM_RBD'], axis=1)

# %%
df = df.drop(['NOM_DEPROV_RBD'], axis=1)

# %%
# columnas object
df.select_dtypes(include=['object']).columns
# Out:
# Index(['LET_CUR', 'NOM_COM_ALU', 'SIT_FIN', 'SIT_FIN_R'], dtype='object')

# %%
df = df.drop(['LET_CUR', 'NOM_COM_ALU', 'SIT_FIN'], axis=1)

# %%
# Convertir a dummies la variable SIT_FIN_R
df = pd.get_dummies(df, columns=['SIT_FIN_R'])

# %%
df['DESERTOR'].value_counts()
# Out:
# DESERTOR
# 0    6155385
# 1     602650
# Name: count, dtype: int64

# %%
# Drop variables: COD_REG_RBD, COD_PRO_RBD, COD_DEPROV_RBD, COD_REG_ALU, COD_COM_ALU, NOM_COM_ALU, COD_RAMA, COD_SEC, COD_ESPE
df = df.drop(['COD_REG_RBD', 'COD_PRO_RBD', 'COD_DEPROV_RBD', 'COD_REG_ALU', 'COD_COM_ALU', 'COD_RAMA', 'COD_SEC', 'COD_ESPE'], axis=1)

# %%
corr_data = df.corr()
corr_data
# Out:
#                             RBD   DGV_RBD  COD_COM_RBD  COD_DEPE  COD_DEPE2  \
# RBD                    1.000000  0.022632     0.377226  0.153141   0.146845
# DGV_RBD                0.022632  1.000000     0.005297  0.004134  -0.007447
# COD_COM_RBD            0.377226  0.005297     1.000000  0.092596   0.109766
# COD_DEPE               0.153141  0.004134     0.092596  1.000000   0.947384
# COD_DEPE2              0.146845 -0.007447     0.109766  0.947384   1.000000
# RURAL_RBD             -0.184406  0.016471    -0.102809 -0.116434  -0.150143
# ESTADO_ESTAB           0.054865  0.003226     0.029168  0.015469   0.012614
# COD_ENSE              -0.006774 -0.008515     0.015605  0.075544   0.091899
# COD_ENSE2              0.003053 -0.006256     0.024384  0.079772   0.096452
# COD_GRADO             -0.030382  0.006353    -0.053584 -0.051808  -0.061792
# COD_JOR               -0.050033  0.001349    -0.019096 -0.097138  -0.103054
# COD_TIP_CUR           -0.098804  0.007021    -0.072727 -0.024998  -0.050606
# COD_DES_CUR           -0.019430 -0.010329     0.000400  0.046187   0.063870
# MRUN                  -0.009830 -0.000347    -0.009158 -0.004932  -0.001184
# GEN_ALU                0.026893 -0.007877     0.036372 -0.001499   0.005007
# EDAD_ALU               0.009188 -0.002474     0.003993  0.050479   0.061938
# PROM_GRAL              0.054050  0.028792     0.035251  0.095128   0.090494
# ASISTENCIA             0.059946  0.025429     0.035024  0.104521   0.097831
# DESERTOR               0.001957 -0.011245     0.016747 -0.031931  -0.019494
# AGNO_NAC_ALU          -0.007236  0.002990    -0.002005 -0.044208  -0.056183
# MES_NAC_ALU           -0.001672 -0.000025    -0.010343 -0.004946  -0.004263
# DIAS_ASISTIDOS_MARZO   0.051700  0.011658     0.014140  0.076334   0.074420
# DIAS_TRABAJADOS_MARZO -0.001598 -0.007849    -0.012736  0.003944  -0.003076
# ASIS_PROMEDIO_MARZO    0.051865  0.012214     0.015232  0.075962   0.074960
# DIAS_ASISTIDOS_ABRIL   0.054584  0.015183     0.014291  0.082793   0.079523
# DIAS_TRABAJADOS_ABRIL  0.038521 -0.010598    -0.077325  0.019033   0.038559
# ASIS_PROMEDIO_ABRIL    0.052898  0.015946     0.018825  0.081741   0.077547
# DIAS_ASISTIDOS_MAYO    0.046216  0.013713     0.006051  0.088216   0.083422
# DIAS_TRABAJADOS_MAYO  -0.143594 -0.001995    -0.225619  0.054187   0.021694
# ASIS_PROMEDIO_MAYO     0.052806  0.014074     0.015698  0.085882   0.082451
# DIAS_ASISTIDOS_JUNIO   0.060074  0.013213     0.022792  0.090230   0.083824
# DIAS_TRABAJADOS_JUNIO  0.100002  0.014407     0.081923  0.053572   0.031401
# ASIS_PROMEDIO_JUNIO    0.051926  0.011589     0.015054  0.086602   0.082322
# DIAS_ASISTIDOS_JULIO   0.035748  0.016002    -0.042597  0.090031   0.087345
# DIAS_TRABAJADOS_JULIO -0.101762 -0.001050    -0.317734  0.013173   0.018085
# ASIS_PROMEDIO_JULIO    0.050787  0.015294     0.014086  0.084116   0.080756
# SIT_FIN_R_             0.000253  0.005563     0.002147 -0.002961  -0.004961
# SIT_FIN_R_P            0.052329  0.027491     0.037739  0.093491   0.089583
# SIT_FIN_R_R            0.011851  0.002241     0.012528  0.004135   0.007547
# SIT_FIN_R_T           -0.068656 -0.029639    -0.049368 -0.098474  -0.097762
# SIT_FIN_R_Y            0.021723 -0.001381     0.011183 -0.005696  -0.000207
#
#                        RURAL_RBD  ESTADO_ESTAB  COD_ENSE  COD_ENSE2  \
# RBD                    -0.184406      0.054865 -0.006774   0.003053
# DGV_RBD                 0.016471      0.003226 -0.008515  -0.006256
# COD_COM_RBD            -0.102809      0.029168  0.015605   0.024384
# COD_DEPE               -0.116434      0.015469  0.075544   0.079772
# COD_DEPE2              -0.150143      0.012614  0.091899   0.096452
# RURAL_RBD               1.000000     -0.012824 -0.134629  -0.161115
# ESTADO_ESTAB           -0.012824      1.000000  0.003370   0.006767
# COD_ENSE               -0.134629      0.003370  1.000000   0.967821
# COD_ENSE2              -0.161115      0.006767  0.967821   1.000000
# COD_GRADO               0.088997     -0.003524 -0.453781  -0.495166
# COD_JOR                 0.133788      0.000836  0.064380   0.065041
# COD_TIP_CUR             0.425683     -0.005632 -0.104568  -0.112260
# COD_DES_CUR            -0.052029      0.006259  0.567257   0.525255
# MRUN                   -0.006426     -0.001033 -0.009484  -0.010776
# GEN_ALU                -0.045822      0.002581  0.033118   0.036510
# EDAD_ALU               -0.148414      0.005804  0.741262   0.788349
# PROM_GRAL              -0.080775     -0.051312 -0.037068  -0.037458
# ASISTENCIA             -0.078333     -0.051006 -0.017810  -0.017308
# DESERTOR               -0.057045     -0.007565  0.221310   0.232260
# AGNO_NAC_ALU            0.142504     -0.005211 -0.736410  -0.782987
# MES_NAC_ALU             0.015828      0.000916 -0.002359  -0.003290
# DIAS_ASISTIDOS_MARZO   -0.091505      0.011790  0.040749   0.044603
# DIAS_TRABAJADOS_MARZO   0.001641     -0.000038 -0.022115  -0.025294
# ASIS_PROMEDIO_MARZO    -0.091754      0.011898  0.041495   0.045585
# DIAS_ASISTIDOS_ABRIL   -0.084383      0.012226  0.024159   0.028250
# DIAS_TRABAJADOS_ABRIL  -0.040904      0.004435 -0.013083  -0.014868
# ASIS_PROMEDIO_ABRIL    -0.082629      0.012093  0.025025   0.029227
# DIAS_ASISTIDOS_MAYO    -0.081850      0.010695  0.025681   0.029605
# DIAS_TRABAJADOS_MAYO    0.020306     -0.021877  0.023124   0.016296
# ASIS_PROMEDIO_MAYO     -0.082588      0.011977  0.024714   0.028972
# DIAS_ASISTIDOS_JUNIO   -0.079319      0.013193  0.021945   0.025553
# DIAS_TRABAJADOS_JUNIO  -0.003317      0.005243 -0.053293  -0.057867
# ASIS_PROMEDIO_JUNIO    -0.078609      0.012728  0.025316   0.029085
# DIAS_ASISTIDOS_JULIO   -0.083836      0.011132  0.027974   0.032066
# DIAS_TRABAJADOS_JULIO  -0.004153     -0.004113 -0.029512  -0.028480
# ASIS_PROMEDIO_JULIO    -0.077309      0.012319  0.027748   0.031441
# SIT_FIN_R_             -0.002711     -0.000398 -0.006558  -0.006970
# SIT_FIN_R_P            -0.078351     -0.048760 -0.031773  -0.032592
# SIT_FIN_R_R            -0.027317     -0.006216  0.074818   0.080609
# SIT_FIN_R_T             0.103789      0.056553 -0.023764  -0.026730
# SIT_FIN_R_Y            -0.025338     -0.006106  0.072383   0.076415
#
#                        COD_GRADO  ...  DIAS_TRABAJADOS_JUNIO  \
# RBD                    -0.030382  ...               0.100002
# DGV_RBD                 0.006353  ...               0.014407
# COD_COM_RBD            -0.053584  ...               0.081923
# COD_DEPE               -0.051808  ...               0.053572
# COD_DEPE2              -0.061792  ...               0.031401
# RURAL_RBD               0.088997  ...              -0.003317
# ESTADO_ESTAB           -0.003524  ...               0.005243
# COD_ENSE               -0.453781  ...              -0.053293
# COD_ENSE2              -0.495166  ...              -0.057867
# COD_GRADO               1.000000  ...               0.017441
# COD_JOR                 0.004029  ...               0.003176
# COD_TIP_CUR             0.042261  ...              -0.015802
# COD_DES_CUR            -0.063587  ...              -0.004964
# MRUN                    0.021057  ...               0.002918
# GEN_ALU                -0.005571  ...               0.000466
# EDAD_ALU                0.013720  ...              -0.069000
# PROM_GRAL               0.009624  ...               0.000101
# ASISTENCIA              0.024077  ...               0.005291
# DESERTOR               -0.134964  ...              -0.019681
# AGNO_NAC_ALU           -0.005344  ...               0.069688
# MES_NAC_ALU             0.015501  ...              -0.006128
# DIAS_ASISTIDOS_MARZO    0.011917  ...              -0.004813
# DIAS_TRABAJADOS_MARZO   0.023394  ...               0.016984
# ASIS_PROMEDIO_MARZO     0.011195  ...              -0.006051
# DIAS_ASISTIDOS_ABRIL    0.018375  ...              -0.002361
# DIAS_TRABAJADOS_ABRIL   0.013494  ...               0.061707
# ASIS_PROMEDIO_ABRIL     0.018415  ...              -0.005675
# DIAS_ASISTIDOS_MAYO     0.021744  ...               0.005936
# DIAS_TRABAJADOS_MAYO    0.024819  ...               0.055937
# ASIS_PROMEDIO_MAYO      0.020988  ...               0.003487
# DIAS_ASISTIDOS_JUNIO    0.019361  ...               0.068714
# DIAS_TRABAJADOS_JUNIO   0.017441  ...               1.000000
# ASIS_PROMEDIO_JUNIO     0.018256  ...               0.006221
# DIAS_ASISTIDOS_JULIO    0.016957  ...              -0.041515
# DIAS_TRABAJADOS_JULIO   0.014439  ...              -0.186867
# ASIS_PROMEDIO_JULIO     0.017888  ...               0.004445
# SIT_FIN_R_              0.002363  ...               0.001191
# SIT_FIN_R_P             0.032325  ...               0.004625
# SIT_FIN_R_R            -0.050179  ...              -0.008554
# SIT_FIN_R_T             0.012751  ...              -0.002699
# SIT_FIN_R_Y            -0.070109  ...               0.002840
#
#                        ASIS_PROMEDIO_JUNIO  DIAS_ASISTIDOS_JULIO  \
# RBD                               0.051926              0.035748
# DGV_RBD                           0.011589              0.016002
# COD_COM_RBD                       0.015054             -0.042597
# COD_DEPE                          0.086602              0.090031
# COD_DEPE2                         0.082322              0.087345
# RURAL_RBD                        -0.078609             -0.083836
# ESTADO_ESTAB                      0.012728              0.011132
# COD_ENSE                          0.025316              0.027974
# COD_ENSE2                         0.029085              0.032066
# COD_GRADO                         0.018256              0.016957
# COD_JOR                          -0.015967             -0.021990
# COD_TIP_CUR                      -0.041108             -0.043144
# COD_DES_CUR                       0.016104              0.017307
# MRUN                              0.008362              0.009097
# GEN_ALU                           0.008122              0.007824
# EDAD_ALU                          0.021271              0.024280
# PROM_GRAL                         0.390530              0.392915
# ASISTENCIA                        0.410824              0.413815
# DESERTOR                         -0.165091             -0.157437
# AGNO_NAC_ALU                     -0.007118             -0.010725
# MES_NAC_ALU                       0.008776              0.008243
# DIAS_ASISTIDOS_MARZO              0.497220              0.486518
# DIAS_TRABAJADOS_MARZO             0.019573              0.016947
# ASIS_PROMEDIO_MARZO               0.496748              0.486328
# DIAS_ASISTIDOS_ABRIL              0.513286              0.501346
# DIAS_TRABAJADOS_ABRIL             0.009001              0.007488
# ASIS_PROMEDIO_ABRIL               0.514100              0.502459
# DIAS_ASISTIDOS_MAYO               0.522710              0.507217
# DIAS_TRABAJADOS_MAYO              0.029082              0.032355
# ASIS_PROMEDIO_MAYO                0.521709              0.506209
# DIAS_ASISTIDOS_JUNIO              0.996080              0.510640
# DIAS_TRABAJADOS_JUNIO             0.006221             -0.041515
# ASIS_PROMEDIO_JUNIO               1.000000              0.517397
# DIAS_ASISTIDOS_JULIO              0.517397              1.000000
# DIAS_TRABAJADOS_JULIO            -0.007377              0.151301
# ASIS_PROMEDIO_JULIO               0.525194              0.975549
# SIT_FIN_R_                        0.001349              0.001883
# SIT_FIN_R_P                       0.374056              0.375993
# SIT_FIN_R_R                      -0.007164             -0.006895
# SIT_FIN_R_T                      -0.360521             -0.362606
# SIT_FIN_R_Y                      -0.085434             -0.085660
#
#                        DIAS_TRABAJADOS_JULIO  ASIS_PROMEDIO_JULIO  \
# RBD                                -0.101762             0.050787
# DGV_RBD                            -0.001050             0.015294
# COD_COM_RBD                        -0.317734             0.014086
# COD_DEPE                            0.013173             0.084116
# COD_DEPE2                           0.018085             0.080756
# RURAL_RBD                          -0.004153            -0.077309
# ESTADO_ESTAB                       -0.004113             0.012319
# COD_ENSE                           -0.029512             0.027748
# COD_ENSE2                          -0.028480             0.031441
# COD_GRADO                           0.014439             0.017888
# COD_JOR                            -0.009453            -0.020016
# COD_TIP_CUR                        -0.005298            -0.037097
# COD_DES_CUR                        -0.008145             0.017153
# MRUN                               -0.010306             0.008789
# GEN_ALU                            -0.008493             0.007793
# EDAD_ALU                           -0.030521             0.023666
# PROM_GRAL                          -0.032988             0.401061
# ASISTENCIA                         -0.035023             0.422788
# DESERTOR                           -0.032798            -0.160732
# AGNO_NAC_ALU                        0.030518            -0.009783
# MES_NAC_ALU                         0.007290             0.008158
# DIAS_ASISTIDOS_MARZO               -0.017596             0.496570
# DIAS_TRABAJADOS_MARZO              -0.026682             0.021303
# ASIS_PROMEDIO_MARZO                -0.015520             0.495919
# DIAS_ASISTIDOS_ABRIL               -0.026130             0.512294
# DIAS_TRABAJADOS_ABRIL              -0.006999             0.011501
# ASIS_PROMEDIO_ABRIL                -0.024788             0.513051
# DIAS_ASISTIDOS_MAYO                -0.019870             0.517308
# DIAS_TRABAJADOS_MAYO                0.011442             0.033807
# ASIS_PROMEDIO_MAYO                 -0.019879             0.516130
# DIAS_ASISTIDOS_JUNIO               -0.028139             0.523882
# DIAS_TRABAJADOS_JUNIO              -0.186867             0.004445
# ASIS_PROMEDIO_JUNIO                -0.007377             0.525194
# DIAS_ASISTIDOS_JULIO                0.151301             0.975549
# DIAS_TRABAJADOS_JULIO               1.000000            -0.019986
# ASIS_PROMEDIO_JULIO                -0.019986             1.000000
# SIT_FIN_R_                          0.001730             0.001538
# SIT_FIN_R_P                        -0.030721             0.383883
# SIT_FIN_R_R                        -0.013502            -0.006273
# SIT_FIN_R_T                         0.040306            -0.370599
# SIT_FIN_R_Y                        -0.006336            -0.087219
#
#                        SIT_FIN_R_   SIT_FIN_R_P  SIT_FIN_R_R  SIT_FIN_R_T  \
# RBD                       0.000253     0.052329     0.011851    -0.068656
# DGV_RBD                   0.005563     0.027491     0.002241    -0.029639
# COD_COM_RBD               0.002147     0.037739     0.012528    -0.049368
# COD_DEPE                 -0.002961     0.093491     0.004135    -0.098474
# COD_DEPE2                -0.004961     0.089583     0.007547    -0.097762
# RURAL_RBD                -0.002711    -0.078351    -0.027317     0.103789
# ESTADO_ESTAB             -0.000398    -0.048760    -0.006216     0.056553
# COD_ENSE                 -0.006558    -0.031773     0.074818    -0.023764
# COD_ENSE2                -0.006970    -0.032592     0.080609    -0.026730
# COD_GRADO                 0.002363     0.032325    -0.050179     0.012751
# COD_JOR                   0.005831    -0.006759     0.002837     0.015252
# COD_TIP_CUR              -0.001807    -0.051739    -0.015068     0.067825
# COD_DES_CUR              -0.002885     0.011884     0.012173    -0.025243
# MRUN                      0.003888     0.004521     0.002858    -0.014780
# GEN_ALU                  -0.001932     0.043702    -0.033402    -0.026225
# EDAD_ALU                 -0.007597    -0.065193     0.088302     0.001828
# PROM_GRAL                -0.016058     0.948948     0.013088    -0.906688
# ASISTENCIA               -0.015968     0.930704     0.046690    -0.901111
# DESERTOR                 -0.003605    -0.382892     0.071821     0.285682
# AGNO_NAC_ALU              0.007674     0.094232    -0.091433    -0.024946
# MES_NAC_ALU              -0.001514     0.015343     0.002300    -0.017320
# DIAS_ASISTIDOS_MARZO     -0.000814     0.368432     0.005535    -0.369530
# DIAS_TRABAJADOS_MARZO    -0.001215     0.016701    -0.000566    -0.016561
# ASIS_PROMEDIO_MARZO      -0.000716     0.366938     0.005377    -0.367865
# DIAS_ASISTIDOS_ABRIL     -0.000102     0.372251    -0.000713    -0.367009
# DIAS_TRABAJADOS_ABRIL    -0.000121     0.034531     0.003403    -0.042047
# ASIS_PROMEDIO_ABRIL      -0.000138     0.371817    -0.000910    -0.366316
# DIAS_ASISTIDOS_MAYO       0.000938     0.371045    -0.005968    -0.360617
# DIAS_TRABAJADOS_MAYO     -0.000542     0.027683    -0.001007    -0.023781
# ASIS_PROMEDIO_MAYO        0.000945     0.369649    -0.005991    -0.359239
# DIAS_ASISTIDOS_JUNIO      0.001427     0.373765    -0.007312    -0.360358
# DIAS_TRABAJADOS_JUNIO     0.001191     0.004625    -0.008554    -0.002699
# ASIS_PROMEDIO_JUNIO       0.001349     0.374056    -0.007164    -0.360521
# DIAS_ASISTIDOS_JULIO      0.001883     0.375993    -0.006895    -0.362606
# DIAS_TRABAJADOS_JULIO     0.001730    -0.030721    -0.013502     0.040306
# ASIS_PROMEDIO_JULIO       0.001538     0.383883    -0.006273    -0.370599
# SIT_FIN_R_                1.000000    -0.016258    -0.002071    -0.007035
# SIT_FIN_R_P              -0.016258     1.000000    -0.253627    -0.861599
# SIT_FIN_R_R              -0.002071    -0.253627     1.000000    -0.109751
# SIT_FIN_R_T              -0.007035    -0.861599    -0.109751     1.000000
# SIT_FIN_R_Y              -0.002072    -0.253710    -0.032318    -0.109787
#
#                        SIT_FIN_R_Y
# RBD                       0.021723
# DGV_RBD                  -0.001381
# COD_COM_RBD               0.011183
# COD_DEPE                 -0.005696
# COD_DEPE2                -0.000207
# RURAL_RBD                -0.025338
# ESTADO_ESTAB             -0.006106
# COD_ENSE                  0.072383
# COD_ENSE2                 0.076415
# COD_GRADO                -0.070109
# COD_JOR                  -0.023861
# COD_TIP_CUR              -0.017882
# COD_DES_CUR               0.020296
# MRUN                      0.022383
# GEN_ALU                  -0.017880
# EDAD_ALU                  0.084140
# PROM_GRAL                -0.266934
# ASISTENCIA               -0.265358
# DESERTOR                  0.235992
# AGNO_NAC_ALU             -0.100633
# MES_NAC_ALU               0.000474
# DIAS_ASISTIDOS_MARZO     -0.059748
# DIAS_TRABAJADOS_MARZO    -0.002296
# ASIS_PROMEDIO_MARZO      -0.059800
# DIAS_ASISTIDOS_ABRIL     -0.070329
# DIAS_TRABAJADOS_ABRIL     0.010451
# ASIS_PROMEDIO_ABRIL      -0.070725
# DIAS_ASISTIDOS_MAYO      -0.078203
# DIAS_TRABAJADOS_MAYO     -0.013212
# ASIS_PROMEDIO_MAYO       -0.077915
# DIAS_ASISTIDOS_JUNIO     -0.084918
# DIAS_TRABAJADOS_JUNIO     0.002840
# ASIS_PROMEDIO_JUNIO      -0.085434
# DIAS_ASISTIDOS_JULIO     -0.085660
# DIAS_TRABAJADOS_JULIO    -0.006336
# ASIS_PROMEDIO_JULIO      -0.087219
# SIT_FIN_R_               -0.002072
# SIT_FIN_R_P              -0.253710
# SIT_FIN_R_R              -0.032318
# SIT_FIN_R_T              -0.109787
# SIT_FIN_R_Y               1.000000
#
# [41 rows x 41 columns]

# %%
corr_data = df.corr()
cmap = sns.diverging_palette(230, 20, as_cmap=True)
sns.heatmap(corr_data, cmap = cmap)
# Out:
# <Axes: >

# %%
# Dividir X y y con variable DESERTOR en y
X = df.drop(['DESERTOR'], axis=1)
y = df['DESERTOR']

# %%
# Dividir en train y test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y,random_state=2023)

# %%
# regresion logistica
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()
logreg.fit(X_train, y_train)

# Predicciones
y_pred = logreg.predict(X_test)

# Matriz de confusion
from sklearn.metrics import confusion_matrix
confusion_matrix = confusion_matrix(y_test, y_pred)
print(confusion_matrix)
# Out:
# /Users/davidlealolivares/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [[1231077       0]
#  [ 120530       0]]

# %%
# Grafico de matriz de confusion
ax = plt.subplot()
sns.heatmap(confusion_matrix, annot=True, ax=ax, cmap='Blues', fmt='g')
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Confusion Matrix')
ax.xaxis.set_ticklabels(['No desertor', 'Desertor'])
ax.yaxis.set_ticklabels(['No desertor', 'Desertor'])
plt.show()

# %%
# Accuracy
from sklearn.metrics import accuracy_score
print(f'Accuracy {accuracy_score(y_test, y_pred)}')

# Precision
from sklearn.metrics import precision_score
precision_score(y_test, y_pred)
print(f'Precision {precision_score(y_test, y_pred)}')

# Recall
from sklearn.metrics import recall_score
recall_score(y_test, y_pred)
print(f'Recall {recall_score(y_test, y_pred)}')

# F1
from sklearn.metrics import f1_score
f1_score(y_test, y_pred)
print(f'F1 {f1_score(y_test, y_pred)}')
# Out:
# Accuracy 0.9108246701888937
# /Users/davidlealolivares/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/davidlealolivares/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Precision 0.0
# Recall 0.0
# F1 0.0

# %%
# Curva ROC
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
logit_roc_auc = roc_auc_score(y_test, logreg.predict(X_test))
fpr, tpr, thresholds = roc_curve(y_test, logreg.predict_proba(X_test)[:,1])
plt.figure(figsize=(10,6))
plt.plot(fpr, tpr, label='Regresion Logistica (area = %0.2f)' % logit_roc_auc)
plt.plot([0,1], [0,1], 'r--')
plt.xlim([0,1])
plt.ylim([0,1.05])
plt.xlabel('Tasa de Falsos Positivos')
plt.ylabel('Tasa de Verdaderos Positivos')
plt.title('Curva ROC')
plt.legend(loc='lower right')
plt.savefig('Log_ROC')
plt.show()

# %%
# KNN
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train, y_train)

# Predicciones
y_pred = knn.predict(X_test)

# Matriz de confusion
from sklearn.metrics import confusion_matrix
confusion_matrix = confusion_matrix(y_test, y_pred)
print(confusion_matrix)

# Accuracy
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred)

# Precision
from sklearn.metrics import precision_score
precision_score(y_test, y_pred)

# Recall
from sklearn.metrics import recall_score
recall_score(y_test, y_pred)

# F1
from sklearn.metrics import f1_score
f1_score(y_test, y_pred)

# Curva ROC
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
knn_roc_auc = roc_auc_score(y_test, knn.predict(X_test))
fpr, tpr, thresholds = roc_curve(y_test, knn.predict_proba(X_test)[:,1])
plt.figure(figsize=(10,6))
plt.plot(fpr, tpr, label='KNN (area = %0.2f)' % knn_roc_auc)
plt.plot([0,1], [0,1], 'r--')
plt.xlim([0,1])
plt.ylim([0,1.05])
plt.xlabel('Tasa de Falsos Positivos')
plt.ylabel('Tasa de Verdaderos Positivos')
plt.title('Curva ROC')
plt.legend(loc='lower right')
plt.savefig('KNN_ROC')
plt.show()

# Arbol de decision
from sklearn.tree import DecisionTreeClassifier
tree = DecisionTreeClassifier(max_depth=4, random_state=2023)
tree.fit(X_train, y_train)

# Predicciones
y_pred = tree.predict(X_test)

# Matriz de confusion
from sklearn.metrics import confusion_matrix
confusion_matrix = confusion_matrix(y_test, y_pred)
print(confusion_matrix)

# Accuracy
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred)

# Precision
from sklearn.metrics import precision_score
precision_score(y_test, y_pred)

# Recall
from sklearn.metrics import recall_score
recall_score(y_test, y_pred)

# F1
from sklearn.metrics import f1_score
f1_score(y_test, y_pred)

# Curva ROC
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
tree_roc_auc = roc_auc_score(y_test, tree.predict(X_test))
fpr, tpr, thresholds = roc_curve(y_test, tree.predict_proba(X_test)[:,1])
plt.figure(figsize=(10,6))
plt.plot(fpr, tpr, label='Arbol de decision (area = %0.2f)' % tree_roc_auc)
plt.plot([0,1], [0,1], 'r--')
plt.xlim([0,1])
plt.ylim([0,1.05])
plt.xlabel('Tasa de Falsos Positivos')
plt.ylabel('Tasa de Verdaderos Positivos')
plt.title('Curva ROC')
plt.legend(loc='lower right')
plt.savefig('Tree_ROC')
plt.show()

# Random Forest
from sklearn.ensemble import RandomForestClassifier
forest = RandomForestClassifier(n_estimators=100, random_state=2023)
forest.fit(X_train, y_train)

# Predicciones
y_pred = forest.predict(X_test)

# Matriz de confusion
from sklearn.metrics import confusion_matrix
confusion_matrix = confusion_matrix(y_test, y_pred)
print(confusion_matrix)

# Accuracy
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred)

# Precision
from sklearn.metrics import precision_score
precision_score(y_test, y_pred)

# Recall
from sklearn.metrics import recall_score
recall_score(y_test, y_pred)

# F1
from sklearn.metrics import f1_score
f1_score(y_test, y_pred)

# Curva ROC
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
forest_roc_auc = roc_auc_score(y_test, forest.predict(X_test))
fpr, tpr, thresholds = roc_curve(y_test, forest.predict_proba(X_test)[:,1])
plt.figure(figsize=(10,6))
plt.plot(fpr, tpr, label='Random Forest (area = %0.2f)' % forest_roc_auc)
plt.plot([0,1], [0,1], 'r--')
plt.xlim([0,1])
plt.ylim([0,1.05])
plt.xlabel('Tasa de Falsos Positivos')
plt.ylabel('Tasa de Verdaderos Positivos')
plt.title('Curva ROC')
plt.legend(loc='lower right')
plt.savefig('Forest_ROC')
plt.show()

# Gradient Boosting
from sklearn.ensemble import GradientBoostingClassifier
gb = GradientBoostingClassifier(n_estimators=100, random_state=2023)
gb.fit(X_train, y_train)

# Predicciones
y_pred = gb.predict(X_test)

# Matriz de confusion
from sklearn.metrics import confusion_matrix
confusion_matrix = confusion_matrix(y_test, y_pred)

# Accuracy
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred)

# Precision
from sklearn.metrics import precision_score
precision_score(y_test, y_pred)

# Recall
from sklearn.metrics import recall_score
recall_score(y_test, y_pred)

# F1
from sklearn.metrics import f1_score
f1_score(y_test, y_pred)

# Curva ROC
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
gb_roc_auc = roc_auc_score(y_test, gb.predict(X_test))
fpr, tpr, thresholds = roc_curve(y_test, gb.predict_proba(X_test)[:,1])
plt.figure(figsize=(10,6))
plt.plot(fpr, tpr, label='Gradient Boosting (area = %0.2f)' % gb_roc_auc)
plt.plot([0,1], [0,1], 'r--')
plt.xlim([0,1])
plt.ylim([0,1.05])
plt.xlabel('Tasa de Falsos Positivos')
plt.ylabel('Tasa de Verdaderos Positivos')
plt.title('Curva ROC')
plt.legend(loc='lower right')
plt.savefig('GB_ROC')
plt.show()

# XGBoost
from xgboost import XGBClassifier
xgb = XGBClassifier(n_estimators=100, random_state=2023)
xgb.fit(X_train, y_train)

# Predicciones
y_pred = xgb.predict(X_test)

# Matriz de confusion
from sklearn.metrics import confusion_matrix
confusion_matrix = confusion_matrix(y_test, y_pred)

# Accuracy
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred)

# Precision
from sklearn.metrics import precision_score
precision_score(y_test, y_pred)

# Recall
from sklearn.metrics import recall_score
recall_score(y_test, y_pred)

# F1
from sklearn.metrics import f1_score
f1_score(y_test, y_pred)

# Curva ROC
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
xgb_roc_auc = roc_auc_score(y_test, xgb.predict(X_test))
fpr, tpr, thresholds = roc_curve(y_test, xgb.predict_proba(X_test)[:,1])
plt.figure(figsize=(10,6))
plt.plot(fpr, tpr, label='XGBoost (area = %0.2f)' % xgb_roc_auc)
plt.plot([0,1], [0,1], 'r--')
plt.xlim([0,1])
plt.ylim([0,1.05])
plt.xlabel('Tasa de Falsos Positivos')
plt.ylabel('Tasa de Verdaderos Positivos')
plt.title('Curva ROC')
plt.legend(loc='lower right')
plt.savefig('XGB_ROC')
plt.show()

# LightGBM
from lightgbm import LGBMClassifier
lgbm = LGBMClassifier(n_estimators=100, random_state=2023)
lgbm.fit(X_train, y_train)

# Predicciones
y_pred = lgbm.predict(X_test)

# Matriz de confusion
from sklearn.metrics import confusion_matrix
confusion_matrix = confusion_matrix(y_test, y_pred)

# Accuracy
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred)

# Precision
from sklearn.metrics import precision_score
precision_score(y_test, y_pred)

# Recall
from sklearn.metrics import recall_score
recall_score(y_test, y_pred)

# F1
from sklearn.metrics import f1_score
f1_score(y_test, y_pred)

# Curva ROC
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
lgbm_roc_auc = roc_auc_score(y_test, lgbm.predict(X_test))
fpr, tpr, thresholds = roc_curve(y_test, lgbm.predict_proba(X_test)[:,1])
plt.figure(figsize=(10,6))
plt.plot(fpr, tpr, label='LightGBM (area = %0.2f)' % lgbm_roc_auc)
plt.plot([0,1], [0,1], 'r--')
plt.xlim([0,1])
plt.ylim([0,1.05])
plt.xlabel('Tasa de Falsos Positivos')
plt.ylabel('Tasa de Verdaderos Positivos')
plt.title('Curva ROC')
plt.legend(loc='lower right')
plt.savefig('LGBM_ROC')
plt.show()

# CatBoost
from catboost import CatBoostClassifier
cat = CatBoostClassifier(n_estimators=100, random_state=2023)
cat.fit(X_train, y_train)

# Predicciones
y_pred = cat.predict(X_test)

# Matriz de confusion
from sklearn.metrics import confusion_matrix
confusion_matrix = confusion_matrix(y_test, y_pred)

# Accuracy
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred)

# Precision
from sklearn.metrics import precision_score
precision_score(y_test, y_pred)

# Recall
from sklearn.metrics import recall_score
recall_score(y_test, y_pred)

# F1
from sklearn.metrics import f1_score
f1_score(y_test, y_pred)

# Curva ROC
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
cat_roc_auc = roc_auc_score(y_test, cat.predict(X_test))
fpr, tpr, thresholds = roc_curve(y_test, cat.predict_proba(X_test)[:,1])
plt.figure(figsize=(10,6))
plt.plot(fpr, tpr, label='CatBoost (area = %0.2f)' % cat_roc_auc)
plt.plot([0,1], [0,1], 'r--')
plt.xlim([0,1])
plt.ylim([0,1.05])
plt.xlabel('Tasa de Falsos Positivos')
plt.ylabel('Tasa de Verdaderos Positivos')
plt.title('Curva ROC')
plt.legend(loc='lower right')
plt.savefig('Cat_ROC')
plt.show()

# Comparacion de modelos
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
plt.figure(figsize=(10,6))
plt.plot(fpr, tpr, label='Regresion Logistica (area = %0.2f)' % logit_roc_auc)
plt.plot(fpr, tpr, label='KNN (area = %0.2f)' % knn_roc_auc)
plt.plot(fpr, tpr, label='Arbol de decision (area = %0.2f)' % tree_roc_auc)
plt.plot(fpr, tpr, label='Random Forest (area = %0.2f)' % forest_roc_auc)
plt.plot(fpr, tpr, label='Gradient Boosting (area = %0.2f)' % gb_roc_auc)
plt.plot(fpr, tpr, label='XGBoost (area = %0.2f)' % xgb_roc_auc)
plt.plot(fpr, tpr, label='LightGBM (area = %0.2f)' % lgbm_roc_auc)
plt.plot(fpr, tpr, label='CatBoost (area = %0.2f)' % cat_roc_auc)
plt.plot([0,1], [0,1], 'r--')
plt.xlim([0,1])
plt.ylim([0,1.05])
plt.title('Comparacion de modelos')
plt.xlabel('Tasa de Falsos Positivos')
plt.ylabel('Tasa de Verdaderos Positivos')
plt.legend(loc='lower right')
plt.savefig('Comparacion')
plt.show()
