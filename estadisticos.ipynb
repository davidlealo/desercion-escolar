# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
from desertores import identificar_desertores_sistema_regular

# %%
from rendimiento import analisis_rendimiento

# %%
m2016 = pd.read_csv('data/matriculas/2016/20160926_matricula_unica_2016_20160430_PUBL.csv', sep=';')
m2017 = pd.read_csv('data/matriculas/2017/20170921_matricula_unica_2017_20170430_PUBL.csv', sep=';')
m2018 = pd.read_csv('data/matriculas/2018/m2018.csv', sep=';')
m2019 = pd.read_csv('data/matriculas/2019/m2019.csv', sep=';')
m2020 = pd.read_csv('data/matriculas/2020/m2020.CSV', sep=';')
m2021 = pd.read_csv('data/matriculas/2021/m2021.csv', sep=';')
m2022 = pd.read_csv('data/matriculas/2022/m2022.csv', sep=';')
m2023 = pd.read_csv('data/matriculas/2023/20230906_Matrícula_unica_2023_20230430_WEB.csv', sep=';')
# Out:
# /var/folders/v5/8__wxdkj3j713bygpr1tsw_80000gn/T/ipykernel_82123/570267165.py:1: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   m2016 = pd.read_csv('data/matriculas/2016/20160926_matricula_unica_2016_20160430_PUBL.csv', sep=';')
# /var/folders/v5/8__wxdkj3j713bygpr1tsw_80000gn/T/ipykernel_82123/570267165.py:2: DtypeWarning: Columns (26) have mixed types. Specify dtype option on import or set low_memory=False.
#   m2017 = pd.read_csv('data/matriculas/2017/20170921_matricula_unica_2017_20170430_PUBL.csv', sep=';')
# /var/folders/v5/8__wxdkj3j713bygpr1tsw_80000gn/T/ipykernel_82123/570267165.py:3: DtypeWarning: Columns (26) have mixed types. Specify dtype option on import or set low_memory=False.
#   m2018 = pd.read_csv('data/matriculas/2018/m2018.csv', sep=';')
# ...

# %% [markdown]
# # Desertores 2016

# %%
identificar_desertores_sistema_regular(m2016, m2017)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/indexes/base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'COD_ENSE2'
#
# ...

# %% [markdown]
# # Desertores 2017

# %%
identificar_desertores_sistema_regular(m2017, m2018)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/indexes/base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'COD_ENSE2'
#
# ...

# %% [markdown]
# # Desertores 2018

# %%
identificar_desertores_sistema_regular(m2018, m2019)
# Out:
# /Users/davidlealolivares/Library/Mobile Documents/com~apple~CloudDocs/Talleres y ayudantias Diplomado DataScience UC2023/desercion-escolar/desertores.py:13: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   desertores = desertores[~((desertores['COD_GRADO'] == 4) & (df_anterior['COD_ENSE2'].isin([5, 7])))]
# Sexo [2018] - [2019]
#               Sexo  Cantidad A. Regulares  Porcentaje A. Regulares  \
# 0  Sin información                      3                 0.000106
# 1           Hombre                1442524                50.881981
# 2            Mujer                1392512                49.117913
#
#    Cantidad A. Desertores  Porcentaje A. Desertores
# 0                       0                  0.000000
# 1                   45903                 57.705507
# 2                   33644                 42.294493
# Gráfico de torta: Sexo alumnos regulares [2018] - [2019]
# Gráfico de torta: Sexo alumnos desertores [2018] - [2019]
# ...

# %% [markdown]
# # Desertores 2019

# %%
identificar_desertores_sistema_regular(m2019, m2020)
# Out:
# /Users/davidlealolivares/Library/Mobile Documents/com~apple~CloudDocs/Talleres y ayudantias Diplomado DataScience UC2023/desercion-escolar/desertores.py:13: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   desertores = desertores[~((desertores['COD_GRADO'] == 4) & (df_anterior['COD_ENSE2'].isin([5, 7])))]
# Sexo [2019] - [2020]
#               Sexo  Cantidad A. Regulares  Porcentaje A. Regulares  \
# 0  Sin información                      5                 0.000175
# 1           Hombre                1461326                51.039225
# 2            Mujer                1401812                48.960600
#
#    Cantidad A. Desertores  Porcentaje A. Desertores
# 0                       0                  0.000000
# 1                   43532                 56.817678
# 2                   33085                 43.182322
# Gráfico de torta: Sexo alumnos regulares [2019] - [2020]
# Gráfico de torta: Sexo alumnos desertores [2019] - [2020]
# ...

# %% [markdown]
# # Desertores 2020

# %%
identificar_desertores_sistema_regular(m2020, m2021)
# Out:
# /Users/davidlealolivares/Library/Mobile Documents/com~apple~CloudDocs/Talleres y ayudantias Diplomado DataScience UC2023/desercion-escolar/desertores.py:13: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   desertores = desertores[~((desertores['COD_GRADO'] == 4) & (df_anterior['COD_ENSE2'].isin([5, 7])))]
# Sexo [2020] - [2021]
#               Sexo  Cantidad A. Regulares  Porcentaje A. Regulares  \
# 0  Sin información                      5                 0.000173
# 1           Hombre                1482327                51.160575
# 2            Mujer                1415069                48.839253
#
#    Cantidad A. Desertores  Porcentaje A. Desertores
# 0                       0                  0.000000
# 1                   30019                 58.805438
# 2                   21029                 41.194562
# Gráfico de torta: Sexo alumnos regulares [2020] - [2021]
# Gráfico de torta: Sexo alumnos desertores [2020] - [2021]
# ...

# %% [markdown]
# # Desertores 2021

# %%
identificar_desertores_sistema_regular(m2021, m2022)
# Out:
# /Users/davidlealolivares/Library/Mobile Documents/com~apple~CloudDocs/Talleres y ayudantias Diplomado DataScience UC2023/desercion-escolar/desertores.py:13: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   desertores = desertores[~((desertores['COD_GRADO'] == 4) & (df_anterior['COD_ENSE2'].isin([5, 7])))]
# Sexo [2021] - [2022]
#               Sexo  Cantidad A. Regulares  Porcentaje A. Regulares  \
# 0  Sin información                      5                 0.000172
# 1           Hombre                1488805                51.132041
# 2            Mujer                1422877                48.867787
#
#    Cantidad A. Desertores  Porcentaje A. Desertores
# 0                       1                  0.001442
# 1                   40841                 58.876699
# 2                   28525                 41.121859
# Gráfico de torta: Sexo alumnos regulares [2021] - [2022]
# Gráfico de torta: Sexo alumnos desertores [2021] - [2022]
# ...

# %% [markdown]
# # Desertores 2022

# %%
identificar_desertores_sistema_regular(m2022, m2023)
# Out:
# /Users/davidlealolivares/Library/Mobile Documents/com~apple~CloudDocs/Talleres y ayudantias Diplomado DataScience UC2023/desercion-escolar/desertores.py:13: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   desertores = desertores[~((desertores['COD_GRADO'] == 4) & (df_anterior['COD_ENSE2'].isin([5, 7])))]
# Sexo [2022] - [2023]
#               Sexo  Cantidad A. Regulares  Porcentaje A. Regulares  \
# 0  Sin información                      7                 0.000240
# 1           Hombre                1491817                51.188863
# 2            Mujer                1422515                48.810897
#
#    Cantidad A. Desertores  Porcentaje A. Desertores
# 0                       0                  0.000000
# 1                   52978                 58.907643
# 2                   36956                 41.092357
# Gráfico de torta: Sexo alumnos regulares [2022] - [2023]
# Gráfico de torta: Sexo alumnos desertores [2022] - [2023]
# ...
