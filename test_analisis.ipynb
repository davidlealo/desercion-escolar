# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
m2018 = pd.read_csv('data/matriculas/2018/m2018.csv', sep=';')
m2019 = pd.read_csv('data/matriculas/2019/m2019.csv', sep=';')
# Out:
# /var/folders/v5/8__wxdkj3j713bygpr1tsw_80000gn/T/ipykernel_82815/3969867569.py:1: DtypeWarning: Columns (26) have mixed types. Specify dtype option on import or set low_memory=False.
#   m2018 = pd.read_csv('data/matriculas/2018/m2018.csv', sep=';')
# /var/folders/v5/8__wxdkj3j713bygpr1tsw_80000gn/T/ipykernel_82815/3969867569.py:2: DtypeWarning: Columns (27) have mixed types. Specify dtype option on import or set low_memory=False.
#   m2019 = pd.read_csv('data/matriculas/2019/m2019.csv', sep=';')

# %%
from analisis import desertores

# %%
desertores(m2018, m2019)
# Out:
# /Users/davidlealolivares/Library/Mobile Documents/com~apple~CloudDocs/Talleres y ayudantias Diplomado DataScience UC2023/desercion-escolar/analisis.py:13: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   desertores = desertores[~((desertores['COD_GRADO'] == 4) & (df_anterior['COD_ENSE2'].isin([5, 7])))]
# /Users/davidlealolivares/Library/Mobile Documents/com~apple~CloudDocs/Talleres y ayudantias Diplomado DataScience UC2023/desercion-escolar/analisis.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   estudiantes_regulares['DESERTOR'] = 0

# %%
# Importar desertores2018
desertores2018 = pd.read_csv('data/tablas/desertores2018.csv')
desertores2018.head()
# Out:
#    Unnamed: 0  AGNO  RBD  DGV_RBD                  NOM_RBD  COD_REG_RBD  \
# 0          15  2018    1        9  LICEO POLITECNICO ARICA           15
# 1          40  2018    1        9  LICEO POLITECNICO ARICA           15
# 2          44  2018    1        9  LICEO POLITECNICO ARICA           15
# 3          46  2018    1        9  LICEO POLITECNICO ARICA           15
# 4          47  2018    1        9  LICEO POLITECNICO ARICA           15
#
#    COD_PRO_RBD  COD_COM_RBD NOM_COM_RBD  COD_DEPROV_RBD  ... FEC_NAC_ALU  \
# 0          151        15101       ARICA             151  ...      200104
# 1          151        15101       ARICA             151  ...      200205
# 2          151        15101       ARICA             151  ...      200105
# 3          151        15101       ARICA             151  ...      200107
# 4          151        15101       ARICA             151  ...      200008
#
#    EDAD_ALU  COD_REG_ALU  COD_COM_ALU   NOM_COM_ALU  COD_SEC  COD_ESPE  \
# ...

# %%
desertores2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79547 entries, 0 to 79546
# Data columns (total 36 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      79547 non-null  int64
#  1   AGNO            79547 non-null  int64
#  2   RBD             79547 non-null  int64
#  3   DGV_RBD         79547 non-null  int64
#  4   NOM_RBD         79547 non-null  object
#  5   COD_REG_RBD     79547 non-null  int64
#  6   COD_PRO_RBD     79547 non-null  int64
#  7   COD_COM_RBD     79547 non-null  int64
#  8   NOM_COM_RBD     79547 non-null  object
#  9   COD_DEPROV_RBD  79547 non-null  int64
#  10  NOM_DEPROV_RBD  79547 non-null  object
#  11  COD_DEPE        79547 non-null  int64
#  12  COD_DEPE2       79547 non-null  int64
#  13  RURAL_RBD       79547 non-null  int64
#  14  ESTADO_ESTAB    79547 non-null  int64
#  15  COD_ENSE        79547 non-null  int64
#  16  COD_ENSE2       79547 non-null  int64
# ...

# %%
# EDAD_ALU valores unicos
desertores2018['EDAD_ALU'].unique()
# Out:
# array(['17', '16', '15', '19', '18', '14', '6', '7', '8', '9', '10', '13',
#        '11', '12', '5', '20', ' ', '21', '92', '3', '0', '35', '24', '23',
#        '22', '34', '1', '46', '44', '25'], dtype=object)

# %%
# EDAD_ALU valores nulos
desertores2018['EDAD_ALU'].isnull().sum()
# Out:
# 0

# %%
# Importar regulares2018
regulares2018 = pd.read_csv('data/tablas/regulares2018.csv')
regulares2018.head()
# Out:
# /var/folders/v5/8__wxdkj3j713bygpr1tsw_80000gn/T/ipykernel_82815/4044017080.py:2: DtypeWarning: Columns (28) have mixed types. Specify dtype option on import or set low_memory=False.
#   regulares2018 = pd.read_csv('data/tablas/regulares2018.csv')
#    Unnamed: 0  AGNO  RBD  DGV_RBD                  NOM_RBD  COD_REG_RBD  \
# 0          15  2019    1        9  LICEO POLITECNICO ARICA           15
# 1          16  2019    1        9  LICEO POLITECNICO ARICA           15
# 2          18  2019    1        9  LICEO POLITECNICO ARICA           15
# 3          19  2019    1        9  LICEO POLITECNICO ARICA           15
# 4          20  2019    1        9  LICEO POLITECNICO ARICA           15
#
#   NOM_REG_RBD_A  COD_PRO_RBD  COD_COM_RBD NOM_COM_RBD  ...  FEC_NAC_ALU  \
# 0           AYP          151        15101       ARICA  ...       200505
# 1           AYP          151        15101       ARICA  ...       200301
# 2           AYP          151        15101       ARICA  ...       200408
# ...

# %%
# Eliminar unnamed de desertores2018
desertores2018.drop('Unnamed: 0', axis=1, inplace=True)
desertores2018.head()
# Out:
#    AGNO  RBD  DGV_RBD                  NOM_RBD  COD_REG_RBD  COD_PRO_RBD  \
# 0  2018    1        9  LICEO POLITECNICO ARICA           15          151
# 1  2018    1        9  LICEO POLITECNICO ARICA           15          151
# 2  2018    1        9  LICEO POLITECNICO ARICA           15          151
# 3  2018    1        9  LICEO POLITECNICO ARICA           15          151
# 4  2018    1        9  LICEO POLITECNICO ARICA           15          151
#
#    COD_COM_RBD NOM_COM_RBD  COD_DEPROV_RBD NOM_DEPROV_RBD  ...  FEC_NAC_ALU  \
# 0        15101       ARICA             151          ARICA  ...       200104
# 1        15101       ARICA             151          ARICA  ...       200205
# 2        15101       ARICA             151          ARICA  ...       200105
# 3        15101       ARICA             151          ARICA  ...       200107
# 4        15101       ARICA             151          ARICA  ...       200008
#
# ...

# %%
# imprimir lista de nombre de variables
list(desertores2018.columns)
# Out:
# ['AGNO',
#  'RBD',
#  'DGV_RBD',
#  'NOM_RBD',
#  'COD_REG_RBD',
#  'COD_PRO_RBD',
#  'COD_COM_RBD',
#  'NOM_COM_RBD',
#  'COD_DEPROV_RBD',
#  'NOM_DEPROV_RBD',
#  'COD_DEPE',
#  'COD_DEPE2',
#  'RURAL_RBD',
#  'ESTADO_ESTAB',
#  'COD_ENSE',
#  'COD_ENSE2',
#  'COD_ENSE3',
#  'COD_GRADO',
#  'COD_GRADO2',
#  'LET_CUR',
#  'COD_JOR',
#  'COD_TIP_CUR',
#  'COD_DES_CUR',
#  'MRUN',
#  'GEN_ALU',
#  'FEC_NAC_ALU',
#  'EDAD_ALU',
#  'COD_REG_ALU',
#  'COD_COM_ALU',
#  'NOM_COM_ALU',
#  'COD_SEC',
#  'COD_ESPE',
#  'COD_RAMA',
#  'ENS',
#  'DESERTOR']

# %%
# 'AGNO', 'RBD', 'DGV_RBD', 'NOM_RBD', 'COD_REG_RBD', 'COD_PRO_RBD', 'COD_COM_RBD', 'NOM_COM_RBD', 'COD_DEPROV_RBD', 'NOM_DEPROV_RBD', 'COD_DEPE', 'COD_DEPE2', 'RURAL_RBD', 'ESTADO_ESTAB', 'COD_ENSE', 'COD_ENSE2', 'COD_ENSE3', 'COD_GRADO', 'COD_GRADO2', 'LET_CUR', 'COD_JOR', 'COD_TIP_CUR', 'COD_DES_CUR', 'MRUN', 'GEN_ALU', 'COD_REG_ALU', 'COD_COM_ALU', 'NOM_COM_ALU', 'COD_SEC', 'COD_ESPE', 'COD_RAMA', 'ENS', 'DESERTOR'

# %%
# Convertir a string las variables: 'AGNO', 'RBD', 'DGV_RBD', 'NOM_RBD', 'COD_REG_RBD', 'COD_PRO_RBD', 'COD_COM_RBD', 'NOM_COM_RBD', 'COD_DEPROV_RBD', 'NOM_DEPROV_RBD', 'COD_DEPE', 'COD_DEPE2', 'RURAL_RBD', 'ESTADO_ESTAB', 'COD_ENSE', 'COD_ENSE2', 'COD_ENSE3', 'COD_GRADO', 'COD_GRADO2', 'LET_CUR', 'COD_JOR', 'COD_TIP_CUR', 'COD_DES_CUR', 'MRUN', 'GEN_ALU', 'COD_REG_ALU', 'COD_COM_ALU', 'NOM_COM_ALU', 'COD_SEC', 'COD_ESPE', 'COD_RAMA', 'ENS', 'DESERTOR'
desertores2018['AGNO'] = desertores2018['AGNO'].astype(str)
desertores2018['RBD'] = desertores2018['RBD'].astype(str)
desertores2018['DGV_RBD'] = desertores2018['DGV_RBD'].astype(str)
desertores2018['NOM_RBD'] = desertores2018['NOM_RBD'].astype(str)
desertores2018['COD_REG_RBD'] = desertores2018['COD_REG_RBD'].astype(str)
desertores2018['COD_PRO_RBD'] = desertores2018['COD_PRO_RBD'].astype(str)
desertores2018['COD_COM_RBD'] = desertores2018['COD_COM_RBD'].astype(str)
desertores2018['NOM_COM_RBD'] = desertores2018['NOM_COM_RBD'].astype(str)
desertores2018['COD_DEPROV_RBD'] = desertores2018['COD_DEPROV_RBD'].astype(str)
desertores2018['NOM_DEPROV_RBD'] = desertores2018['NOM_DEPROV_RBD'].astype(str)
desertores2018['COD_DEPE'] = desertores2018['COD_DEPE'].astype(str)
desertores2018['COD_DEPE2'] = desertores2018['COD_DEPE2'].astype(str)
desertores2018['RURAL_RBD'] = desertores2018['RURAL_RBD'].astype(str)
desertores2018['ESTADO_ESTAB'] = desertores2018['ESTADO_ESTAB'].astype(str)
desertores2018['COD_ENSE'] = desertores2018['COD_ENSE'].astype(str)
desertores2018['COD_ENSE2'] = desertores2018['COD_ENSE2'].astype(str)
desertores2018['COD_ENSE3'] = desertores2018['COD_ENSE3'].astype(str)
desertores2018['COD_GRADO'] = desertores2018['COD_GRADO'].astype(str)
desertores2018['COD_GRADO2'] = desertores2018['COD_GRADO2'].astype(str)
desertores2018['LET_CUR'] = desertores2018['LET_CUR'].astype(str)
desertores2018['COD_JOR'] = desertores2018['COD_JOR'].astype(str)
desertores2018['COD_TIP_CUR'] = desertores2018['COD_TIP_CUR'].astype(str)
desertores2018['COD_DES_CUR'] = desertores2018['COD_DES_CUR'].astype(str)
desertores2018['MRUN'] = desertores2018['MRUN'].astype(str)
desertores2018['GEN_ALU'] = desertores2018['GEN_ALU'].astype(str)
desertores2018['COD_REG_ALU'] = desertores2018['COD_REG_ALU'].astype(str)
desertores2018['COD_COM_ALU'] = desertores2018['COD_COM_ALU'].astype(str)
desertores2018['NOM_COM_ALU'] = desertores2018['NOM_COM_ALU'].astype(str)
desertores2018['COD_SEC'] = desertores2018['COD_SEC'].astype(str)
desertores2018['COD_ESPE'] = desertores2018['COD_ESPE'].astype(str)
desertores2018['COD_RAMA'] = desertores2018['COD_RAMA'].astype(str)
desertores2018['ENS'] = desertores2018['ENS'].astype(str)
desertores2018['DESERTOR'] = desertores2018['DESERTOR'].astype(str)

# %%
# imprimir valores unicos de EDAD_ALU
desertores2018['EDAD_ALU'].unique()
# Out:
# array(['17', '16', '15', '19', '18', '14', '6', '7', '8', '9', '10', '13',
#        '11', '12', '5', '20', ' ', '21', '92', '3', '0', '35', '24', '23',
#        '22', '34', '1', '46', '44', '25'], dtype=object)

# %%
# info desertores2018
desertores2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79547 entries, 0 to 79546
# Data columns (total 35 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   AGNO            79547 non-null  object
#  1   RBD             79547 non-null  object
#  2   DGV_RBD         79547 non-null  object
#  3   NOM_RBD         79547 non-null  object
#  4   COD_REG_RBD     79547 non-null  object
#  5   COD_PRO_RBD     79547 non-null  object
#  6   COD_COM_RBD     79547 non-null  object
#  7   NOM_COM_RBD     79547 non-null  object
#  8   COD_DEPROV_RBD  79547 non-null  object
#  9   NOM_DEPROV_RBD  79547 non-null  object
#  10  COD_DEPE        79547 non-null  object
#  11  COD_DEPE2       79547 non-null  object
#  12  RURAL_RBD       79547 non-null  object
#  13  ESTADO_ESTAB    79547 non-null  object
#  14  COD_ENSE        79547 non-null  object
#  15  COD_ENSE2       79547 non-null  object
#  16  COD_ENSE3       79547 non-null  object
# ...

# %%
# Kprototypes de desertores2018

from kmodes.kprototypes import KPrototypes
from sklearn.preprocessing import StandardScaler

# Crear matriz de datos
data = desertores2018.iloc[:, 1:].values

# Crear matriz de datos categóricos
data_cat = desertores2018.iloc[:, 1:5].values

# Crear matriz de datos numéricos
data_num = desertores2018.iloc[:, 5:].values

# Crear objeto de la clase StandardScaler
sc = StandardScaler()

# Ajustar y transformar los datos numéricos
data_num = sc.fit_transform(data_num)

# Crear objeto de la clase KPrototypes
kproto = KPrototypes(n_clusters=5, init='Cao')

# Ajustar el modelo a los datos
kproto.fit(data, categorical=[0, 1, 2, 3])

# Obtener las etiquetas de los clusters
clusters = kproto.labels_

# Obtener los centroides
centroids = kproto.cluster_centroids_

# Visualizar los centroides
print(centroids)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/davidlealolivares/Library/Mobile Documents/com~apple~CloudDocs/Talleres y ayudantias Diplomado DataScience UC2023/desercion-escolar/test_analisis.ipynb Cell 14 line 1
#      <a href='vscode-notebook-cell:/Users/davidlealolivares/Library/Mobile%20Documents/com~apple~CloudDocs/Talleres%20y%20ayudantias%20Diplomado%20DataScience%20UC2023/desercion-escolar/test_analisis.ipynb#W6sZmlsZQ%3D%3D?line=15'>16</a> sc = StandardScaler()
#      <a href='vscode-notebook-cell:/Users/davidlealolivares/Library/Mobile%20Documents/com~apple~CloudDocs/Talleres%20y%20ayudantias%20Diplomado%20DataScience%20UC2023/desercion-escolar/test_analisis.ipynb#W6sZmlsZQ%3D%3D?line=17'>18</a> # Ajustar y transformar los datos numéricos
# ...
